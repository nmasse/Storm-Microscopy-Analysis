# %%
import importlib
import cluster
import numpy as np
import matplotlib.pyplot as plt
importlib.reload(cluster)
# Out:
# <module 'cluster' from '/home/masse/Storm/cluster.py'>

# %%
c = cluster.Cluster('PSD95_Run3.csv')
# Out:
# Coordinate shape  (130620, 3)

# %%
y = c.chigirev_dim_reduction()
# Out:
# Iteration  0  D  19464.16713931948  I  6.872479971004744  Loss  156913.76655941436
# Iteration  1  D  19348.20173341721  I  6.775353096479026  Loss  154855.26366299772
# Iteration  2  D  19533.823111282534  I  6.743546102074297  Loss  154404.74515276848
# Iteration  3  D  19661.2516108266  I  6.72746754243545  Loss  154210.60245953558
# Iteration  4  D  19751.002015490754  I  6.717450785749141  Loss  154100.01773047357
# Iteration  5  D  19818.20417358364  I  6.7104384986385375  Loss  154026.97414635436
# Iteration  6  D  19870.725334716837  I  6.705192474663911  Loss  153974.57482799506
# Iteration  7  D  19913.02596838593  I  6.701098413133972  Loss  153934.99423106536
# Iteration  8  D  19947.837448932096  I  6.697810662707167  Loss  153904.05070307542
# Iteration  9  D  19977.027338297892  I  6.695109692024599  Loss  153879.22117878989
# Iteration  10  D  20002.07942129232  I  6.692834092328817  Loss  153858.76126786866
# Iteration  11  D  20024.039842781727  I  6.690873909079668  Loss  153841.51802437508
# Iteration  12  D  20043.577537552595  I  6.689161227689615  Loss  153826.8020913449
# Iteration  13  D  20061.20600576253  I  6.687642008198882  Loss  153814.04616974018
# Iteration  14  D  20077.451341057465  I  6.686258083230232  Loss  153802.6130056621
# Iteration  15  D  20092.47202148891  I  6.684987516115089  Loss  153792.2223437907
# Iteration  16  D  20106.541230097715  I  6.683798635832789  Loss  153782.5139467535
# Iteration  17  D  20119.857929316495  I  6.682664420392951  Loss  153773.1463371755
# Iteration  18  D  20132.60385282681  I  6.681569357318013  Loss  153763.99099918708
# Iteration  19  D  20144.85061769202  I  6.680501737988173  Loss  153754.88537745547
# Iteration  20  D  20156.54086611208  I  6.679475228020527  Loss  153746.0454265226
# Iteration  21  D  20167.680788773538  I  6.67850034060589  Loss  153737.68760089134
# Iteration  22  D  20178.063660971453  I  6.677598631033581  Loss  153730.03628164306
# Iteration  23  D  20187.789673205712  I  6.676763835713885  Loss  153723.06638748338
# Iteration  24  D  20196.844137013395  I  6.675996324435143  Loss  153716.77062571625
# Iteration  25  D  20205.42581531587  I  6.675275787515154  Loss  153710.94156561894
# Iteration  26  D  20213.56564592703  I  6.67459988831796  Loss  153705.56341228625
# Iteration  27  D  20221.32741680322  I  6.6739612496200165  Loss  153700.55240920355
# Iteration  28  D  20228.72598184094  I  6.673355605734184  Loss  153695.83809652462
# Iteration  29  D  20235.76368016499  I  6.67278958320702  Loss  153691.5553443054
# Iteration  30  D  20242.358763466826  I  6.6722616152122916  Loss  153687.59106771267
# Iteration  31  D  20248.82218555846  I  6.671749243726153  Loss  153683.80706008154
# Iteration  32  D  20254.919058292395  I  6.671266536067364  Loss  153680.24977963968
# Iteration  33  D  20260.855563608777  I  6.670797841049557  Loss  153676.81238459994
# Iteration  34  D  20266.48181270815  I  6.670354404489818  Loss  153673.5699025045
# Iteration  35  D  20271.953528783415  I  6.669923661410447  Loss  153670.42675699235
# Iteration  36  D  20277.23120988469  I  6.669508393669467  Loss  153667.39908327404
# Iteration  37  D  20282.3202425463  I  6.669108223335008  Loss  153664.48470924646
# Iteration  38  D  20287.285361778486  I  6.668718896404207  Loss  153661.66328986263
# Iteration  39  D  20292.097073805282  I  6.668342709952041  Loss  153658.9512728461
# Iteration  40  D  20296.768907347017  I  6.667976317332907  Loss  153656.29525400518
# Iteration  41  D  20301.280120190684  I  6.667623560956298  Loss  153653.75133931666
# Iteration  42  D  20305.640590647876  I  6.667282345299718  Loss  153651.28749664224
# Iteration  43  D  20309.968805882716  I  6.666944195872862  Loss  153648.85272333998
# Iteration  44  D  20314.119544824396  I  6.666620315712098  Loss  153646.52585906634
# Iteration  45  D  20318.17897327745  I  6.666304521274703  Loss  153644.26939877152
# Iteration  46  D  20322.074812831917  I  6.666001476438564  Loss  153642.10434160318
# Iteration  47  D  20325.843830711823  I  6.665708359100022  Loss  153640.01101271226
# Iteration  48  D  20329.47648054959  I  6.66542690668027  Loss  153638.01461415496
# Iteration  49  D  20332.991966430312  I  6.665154786328867  Loss  153636.08769300763

# %%
x = c.return_coords()

# %%
print(np.std(x[:1000,:],axis=0))
# Out:
# [3638.8638  4482.5957   249.87956]

# %%
u =  np.arange(0,130000,1)
plt.figure(figsize=(20,10))
plt.plot(x[u,0],x[u,1],'b.')
plt.plot(y[u,0],y[u,1],'r.')
plt.axes().set_aspect('equal', 'datalim')
#plt.xlim([5000,10000])
#plt.ylim([5000,10000])
plt.show()
# Out:
# /home/masse/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
c=None

# %%
plt.plot(np.mean(distances,axis=0))
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nbrs = NearestNeighbors(n_neighbors=250, algorithm='kd_tree').fit(x)

# %%
dist, ind = nbrs.kneighbors(x)

# %%
print(dist.shape)
# Out:
# (130620, 250)

# %%
plt.plot(dist[0,:])
plt.plot(dist[1,:],'r')
plt.plot(dist[2,:],'g')
plt.plot(dist[3,:],'k')
plt.plot(dist[4,:],'c')
plt.plot(dist[5,:],'y')
plt.show()

# %%
s=np.diff(dist,n=1,axis=1)

# %%
plt.imshow(s[:10,:100],aspect='auto', interpolation='none', clim = (0,20))
plt.colorbar()
plt.show()

# %%
u =  np.arange(0,130000,1)
plt.figure(figsize=(20,10))
plt.plot(x[u,0],x[u,1],'b.')
plt.axes().set_aspect('equal', 'datalim')
plt.xlim([5000,10000])
plt.ylim([5000,10000])
plt.show()
# Out:
# /home/masse/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
ind = np.where(dist[:,2]<50)[0]
print(len(ind))
plt.figure(figsize=(20,10))
plt.plot(x[:,0],x[:,1],'b.')
plt.plot(x[ind,0],x[ind,1],'r.')
plt.axes().set_aspect('equal', 'datalim')
#plt.xlim([6000,7000])
#plt.ylim([7000,8000])
plt.show()
# Out:
# 95409
# /home/masse/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import nearest_neighbor
import importlib
importlib.reload(nearest_neighbor)
# Out:
# <module 'nearest_neighbor' from '/home/masse/Storm/nearest_neighbor.py'>

# %%
d = '/home/masse/Storm/Data'
NN = nearest_neighbor.NN(d)

# %%
NN_dist, subdirs = NN.search_dirs()
# Out:
# ['BIN1_MAP2', 'BIN1-SYP', 'BIN1_CaMKII', 'BIN1-Syn', 'BIn1-Bassoon_CSVFiles', 'BIN1-Amph1', 'BIN1-GluA1', 'BIN1-PSD95']
# Current directory  BIN1-SYP
# Percentage of coords kept =  0.07245902360250268
# Percentage of coords kept =  0.0491652397260274
# Percentage of coords kept =  0.04446190934539
# Percentage of coords kept =  0.04961251435132032
# BIN1-SYP  mean NN dist =  237.04347391717832  num synaptic markers  2877.0
# Current directory  BIN1_CaMKII
# Percentage of coords kept =  0.06550509063088512
# Percentage of coords kept =  0.08299624596222681
# Percentage of coords kept =  0.15780994316160601
# Percentage of coords kept =  0.051152179649791865
# BIN1_CaMKII  mean NN dist =  281.4520121500277  num synaptic markers  32940.5
# Current directory  BIN1-Syn
# Percentage of coords kept =  0.15484988574627576
# Percentage of coords kept =  0.09235464537673883
# Percentage of coords kept =  0.19836135796015567
# Percentage of coords kept =  0.13293075502280524
# Percentage of coords kept =  0.12516243191683485
# Percentage of coords kept =  0.1619541223090061
# BIN1-Syn  mean NN dist =  460.0823821087886  num synaptic markers  76035.33333333333
# Current directory  BIn1-Bassoon_CSVFiles
# Percentage of coords kept =  0.06937860581339801
# Percentage of coords kept =  0.1287513397642015
# Percentage of coords kept =  0.1559109605613356
# Percentage of coords kept =  0.07552322697966606
# BIn1-Bassoon_CSVFiles  mean NN dist =  192.7109070235884  num synaptic markers  30524.5
# Current directory  BIN1-Amph1
# Percentage of coords kept =  0.06937860581339801
# Percentage of coords kept =  0.040290274544348664
# Percentage of coords kept =  0.07552322697966606
# Percentage of coords kept =  0.03144810845371103
# BIN1-Amph1  mean NN dist =  228.70610871100612  num synaptic markers  4332.5
# Current directory  BIN1-GluA1
# Percentage of coords kept =  0.12332782133699974
# Percentage of coords kept =  0.08933247280103264
# Percentage of coords kept =  0.11279523971761574
# Percentage of coords kept =  0.06407482820055994
# BIN1-GluA1  mean NN dist =  569.1729658106825  num synaptic markers  5348.0
# Current directory  BIN1-PSD95
# Percentage of coords kept =  0.15930690449658455
# Percentage of coords kept =  0.13340989128770478
# Percentage of coords kept =  0.08243273122724053
# Percentage of coords kept =  0.06332420003525133
# Percentage of coords kept =  0.09568541943577413
# Percentage of coords kept =  0.16960671116352494
# BIN1-PSD95  mean NN dist =  143.3509625795231  num synaptic markers  9261.666666666666
